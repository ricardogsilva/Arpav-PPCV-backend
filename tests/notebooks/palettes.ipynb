# %% [markdown]
# # Palette testing

# %%
# %matplotlib widget

import logging

import httpx
import sqlmodel

from arpav_ppcv import (
    config,
    database,
    palette
)
from arpav_ppcv.observations_harvester import operations

logging.basicConfig(level=logging.DEBUG)
logging.getLogger("httpx").setLevel(logging.WARNING)
logging.getLogger("httpcore").setLevel(logging.WARNING)
logging.getLogger("matplotlib").setLevel(logging.WARNING)

settings = config.get_settings()
session = sqlmodel.Session(database.get_engine(settings))
client = httpx.Client()

# %%
for cov_conf in database.collect_all_coverage_configurations(session):
    print(cov_conf.name)
    if (maximum := cov_conf.color_scale_max) - (minimum := cov_conf.color_scale_min) < 0.00001:
        print("\n\n\nSKIPPING\n\n\n")
    else:
        parsed_palette = palette.parse_palette(cov_conf.palette, settings.palettes_dir)
        print(parsed_palette)
        applied_palette = palette.apply_palette(parsed_palette, cov_conf.color_scale_min, cov_conf.color_scale_max, num_stops=5) 
        print(applied_palette)
    print("-----")
# Out:
# cdd_30yr_anomaly_seasonal_agree_model_ensemble
# ['#FF003c30', '#FF01665e', '#FF35978f', '#FF80cdc1', '#FFc7eae5', '#FFf5f5f5', '#FFf6e8c3', '#FFdfc27d', '#FFbf812d', '#FF8c510a', '#FF543005']
# [(-40.0, '#ff003c30'), (-20.0, '#ff35978f'), (0.0, '#fff5f5f5'), (20.0, '#ffbf812d'), (40.0, '#ff543005')]
# -----
# cdd_30yr_anomaly_seasonal_model_ec_earth_cclm4_8_17
# ['#FF003c30', '#FF01665e', '#FF35978f', '#FF80cdc1', '#FFc7eae5', '#FFf5f5f5', '#FFf6e8c3', '#FFdfc27d', '#FFbf812d', '#FF8c510a', '#FF543005']
# [(-40.0, '#ff003c30'), (-20.0, '#ff35978f'), (0.0, '#fff5f5f5'), (20.0, '#ffbf812d'), (40.0, '#ff543005')]
# -----
# cdd_30yr_anomaly_seasonal_model_ec_earth_racmo22e
# ['#FF003c30', '#FF01665e', '#FF35978f', '#FF80cdc1', '#FFc7eae5', '#FFf5f5f5', '#FFf6e8c3', '#FFdfc27d', '#FFbf812d', '#FF8c510a', '#FF543005']
# [(-40.0, '#ff003c30'), (-20.0, '#ff35978f'), (0.0, '#fff5f5f5'), (20.0, '#ffbf812d'), (40.0, '#ff543005')]
# -----
# cdd_30yr_anomaly_seasonal_model_ec_earth_rca4
# ['#FF003c30', '#FF01665e', '#FF35978f', '#FF80cdc1', '#FFc7eae5', '#FFf5f5f5', '#FFf6e8c3', '#FFdfc27d', '#FFbf812d', '#FF8c510a', '#FF543005']
# [(-40.0, '#ff003c30'), (-20.0, '#ff35978f'), (0.0, '#fff5f5f5'), (20.0, '#ffbf812d'), (40.0, '#ff543005')]
# -----
# cdd_30yr_anomaly_seasonal_model_hadgem2_es_racmo22e
# ['#FF003c30', '#FF01665e', '#FF35978f', '#FF80cdc1', '#FFc7eae5', '#FFf5f5f5', '#FFf6e8c3', '#FFdfc27d', '#FFbf812d', '#FF8c510a', '#FF543005']
# [(-40.0, '#ff003c30'), (-20.0, '#ff35978f'), (0.0, '#fff5f5f5'), (20.0, '#ffbf812d'), (40.0, '#ff543005')]
# -----
# cdd_30yr_anomaly_seasonal_model_mpi_esm_lr_remo2009
# ['#FF003c30', '#FF01665e', '#FF35978f', '#FF80cdc1', '#FFc7eae5', '#FFf5f5f5', '#FFf6e8c3', '#FFdfc27d', '#FFbf812d', '#FF8c510a', '#FF543005']
# [(-40.0, '#ff003c30'), (-20.0, '#ff35978f'), (0.0, '#fff5f5f5'), (20.0, '#ffbf812d'), (40.0, '#ff543005')]
# -----
# cdds_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (80.0, '#fffed976'), (160.0, '#fffd8d3c'), (240.0, '#ffe31a1c'), (320.0, '#ff800026')]
# -----
# cdds_30yr_anomaly_annual_agree_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_30yr_anomaly_annual_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_30yr_anomaly_annual_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_30yr_anomaly_annual_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_30yr_anomaly_annual_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_30yr_anomaly_annual_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (250.0, '#fffed976'), (500.0, '#fffd8d3c'), (750.0, '#ffe31a1c'), (1000.0, '#ff800026')]
# -----
# cdds_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (80.0, '#fffed976'), (160.0, '#fffd8d3c'), (240.0, '#ffe31a1c'), (320.0, '#ff800026')]
# -----
# fd_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (65.0, '#fffed976'), (130.0, '#fffd8d3c'), (195.0, '#ffe31a1c'), (260.0, '#ff800026')]
# -----
# fd_30yr_anomaly_annual_agree_model_ensemble
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-85.0, '#ff800026'), (-62.5, '#ffe31a1c'), (-40.0, '#fffd8d3c'), (-17.5, '#fffed976'), (5.0, '#ffffffcc')]
# -----
# fd_30yr_anomaly_annual_model_ec_earth_cclm4_8_17
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-85.0, '#ff800026'), (-62.5, '#ffe31a1c'), (-40.0, '#fffd8d3c'), (-17.5, '#fffed976'), (5.0, '#ffffffcc')]
# -----
# fd_30yr_anomaly_annual_model_ec_earth_racmo22e
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-85.0, '#ff800026'), (-62.5, '#ffe31a1c'), (-40.0, '#fffd8d3c'), (-17.5, '#fffed976'), (5.0, '#ffffffcc')]
# -----
# fd_30yr_anomaly_annual_model_ec_earth_rca4
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-85.0, '#ff800026'), (-62.5, '#ffe31a1c'), (-40.0, '#fffd8d3c'), (-17.5, '#fffed976'), (5.0, '#ffffffcc')]
# -----
# fd_30yr_anomaly_annual_model_hadgem2_es_racmo22e
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-85.0, '#ff800026'), (-62.5, '#ffe31a1c'), (-40.0, '#fffd8d3c'), (-17.5, '#fffed976'), (5.0, '#ffffffcc')]
# -----
# fd_30yr_anomaly_annual_model_mpi_esm_lr_remo2009
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-85.0, '#ff800026'), (-62.5, '#ffe31a1c'), (-40.0, '#fffd8d3c'), (-17.5, '#fffed976'), (5.0, '#ffffffcc')]
# -----
# fd_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_absolute_model_ec_earth_racmo22e
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_absolute_model_ec_earth_rca4
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_absolute_model_ensemble
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_absolute_model_ensemble_lower_uncertainty
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_absolute_model_ensemble_upper_uncertainty
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_absolute_model_hadgem2_es_racmo22e
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (50.0, '#ff2171b5'), (100.0, '#ff6baed6'), (150.0, '#ffc6dbef'), (200.0, '#fff7fbff')]
# -----
# fd_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (65.0, '#fffed976'), (130.0, '#fffd8d3c'), (195.0, '#ffe31a1c'), (260.0, '#ff800026')]
# -----
# hdds_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(2130.0, '#ffffffcc'), (3547.5, '#fffed976'), (4965.0, '#fffd8d3c'), (6382.5, '#ffe31a1c'), (7800.0, '#ff800026')]
# -----
# hdds_30yr_anomaly_annual_agree_model_ensemble
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-2000.0, '#ff800026'), (-1500.0, '#ffe31a1c'), (-1000.0, '#fffd8d3c'), (-500.0, '#fffed976'), (0.0, '#ffffffcc')]
# -----
# hdds_30yr_anomaly_annual_model_ec_earth_cclm4_8_17
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-2000.0, '#ff800026'), (-1500.0, '#ffe31a1c'), (-1000.0, '#fffd8d3c'), (-500.0, '#fffed976'), (0.0, '#ffffffcc')]
# -----
# hdds_30yr_anomaly_annual_model_ec_earth_racmo22e
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-2000.0, '#ff800026'), (-1500.0, '#ffe31a1c'), (-1000.0, '#fffd8d3c'), (-500.0, '#fffed976'), (0.0, '#ffffffcc')]
# -----
# hdds_30yr_anomaly_annual_model_ec_earth_rca4
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-2000.0, '#ff800026'), (-1500.0, '#ffe31a1c'), (-1000.0, '#fffd8d3c'), (-500.0, '#fffed976'), (0.0, '#ffffffcc')]
# -----
# hdds_30yr_anomaly_annual_model_hadgem2_es_racmo22e
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-2000.0, '#ff800026'), (-1500.0, '#ffe31a1c'), (-1000.0, '#fffd8d3c'), (-500.0, '#fffed976'), (0.0, '#ffffffcc')]
# -----
# hdds_30yr_anomaly_annual_model_mpi_esm_lr_remo2009
# ['#FF800026', '#FFbd0026', '#FFe31a1c', '#FFfc4e2a', '#FFfd8d3c', '#FFfeb24c', '#FFfed976', '#FFffeda0', '#FFffffcc']
# [(-2000.0, '#ff800026'), (-1500.0, '#ffe31a1c'), (-1000.0, '#fffd8d3c'), (-500.0, '#fffed976'), (0.0, '#ffffffcc')]
# -----
# hdds_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_absolute_model_ec_earth_racmo22e
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_absolute_model_ec_earth_rca4
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_absolute_model_ensemble
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_absolute_model_ensemble_lower_uncertainty
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_absolute_model_ensemble_upper_uncertainty
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_absolute_model_hadgem2_es_racmo22e
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FF08306b', '#FF08519c', '#FF2171b5', '#FF4292c6', '#FF6baed6', '#FF9ecae1', '#FFc6dbef', '#FFdeebf7', '#FFf7fbff']
# [(0.0, '#ff08306b'), (1750.0, '#ff2171b5'), (3500.0, '#ff6baed6'), (5250.0, '#ffc6dbef'), (7000.0, '#fff7fbff')]
# -----
# hdds_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(2130.0, '#ffffffcc'), (3547.5, '#fffed976'), (4965.0, '#fffd8d3c'), (6382.5, '#ffe31a1c'), (7800.0, '#ff800026')]
# -----
# hwdi_30yr_anomaly_seasonal_agree_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# hwdi_30yr_anomaly_seasonal_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# hwdi_30yr_anomaly_seasonal_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# hwdi_30yr_anomaly_seasonal_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# hwdi_30yr_anomaly_seasonal_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# hwdi_30yr_anomaly_seasonal_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# pr_30yr_anomaly_seasonal_agree_model_ensemble
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_30yr_anomaly_seasonal_model_ec_earth_cclm4_8_17
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_30yr_anomaly_seasonal_model_ec_earth_racmo22e
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_30yr_anomaly_seasonal_model_ec_earth_rca4
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_30yr_anomaly_seasonal_model_hadgem2_es_racmo22e
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_30yr_anomaly_seasonal_model_mpi_esm_lr_remo2009
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_annual_absolute_model_ec_earth_racmo22e
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (800.0, '#ffffffd9'), (1600.0, '#ff41b6c4'), (2400.0, '#ff081d58'), (3200.0, '#ff081d58')]
# -----
# pr_annual_absolute_model_ec_earth_rca4
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (800.0, '#ffffffd9'), (1600.0, '#ff41b6c4'), (2400.0, '#ff081d58'), (3200.0, '#ff081d58')]
# -----
# pr_annual_absolute_model_ensemble
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (800.0, '#ffffffd9'), (1600.0, '#ff41b6c4'), (2400.0, '#ff081d58'), (3200.0, '#ff081d58')]
# -----
# pr_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (800.0, '#ffffffd9'), (1600.0, '#ff41b6c4'), (2400.0, '#ff081d58'), (3200.0, '#ff081d58')]
# -----
# pr_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (800.0, '#ffffffd9'), (1600.0, '#ff41b6c4'), (2400.0, '#ff081d58'), (3200.0, '#ff081d58')]
# -----
# pr_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (800.0, '#ffffffd9'), (1600.0, '#ff41b6c4'), (2400.0, '#ff081d58'), (3200.0, '#ff081d58')]
# -----
# pr_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (800.0, '#ffffffd9'), (1600.0, '#ff41b6c4'), (2400.0, '#ff081d58'), (3200.0, '#ff081d58')]
# -----
# prcptot_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(300.0, '#ffffffcc'), (550.0, '#fffed976'), (800.0, '#fffd8d3c'), (1050.0, '#ffe31a1c'), (1300.0, '#ff800026')]
# -----
# prcptot_annual_monthly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(300.0, '#ffffffcc'), (550.0, '#fffed976'), (800.0, '#fffd8d3c'), (1050.0, '#ffe31a1c'), (1300.0, '#ff800026')]
# -----
# prcptot_annual_seasonal
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(300.0, '#ffffffcc'), (550.0, '#fffed976'), (800.0, '#fffd8d3c'), (1050.0, '#ffe31a1c'), (1300.0, '#ff800026')]
# -----
# prcptot_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(300.0, '#ffffffcc'), (550.0, '#fffed976'), (800.0, '#fffd8d3c'), (1050.0, '#ffe31a1c'), (1300.0, '#ff800026')]
# -----
# pr_seasonal_absolute_model_ec_earth_cclm4_8_17
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_absolute_model_ec_earth_racmo22e
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_absolute_model_ec_earth_rca4
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_absolute_model_ensemble
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_absolute_model_ensemble_lower_uncertainty
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_absolute_model_ensemble_upper_uncertainty
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_absolute_model_hadgem2_es_racmo22e
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_absolute_model_mpi_esm_lr_remo2009
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (200.0, '#ffffffd9'), (400.0, '#ff41b6c4'), (600.0, '#ff081d58'), (800.0, '#ff081d58')]
# -----
# pr_seasonal_anomaly_model_ec_earth_cclm4_8_17
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_seasonal_anomaly_model_ec_earth_racmo22e
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_seasonal_anomaly_model_ec_earth_rca4
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_seasonal_anomaly_model_ensemble
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_seasonal_anomaly_model_ensemble_lower_uncertainty
#
#
#
# SKIPPING
#
#
#
# -----
# pr_seasonal_anomaly_model_ensemble_upper_uncertainty
#
#
#
# SKIPPING
#
#
#
# -----
# pr_seasonal_anomaly_model_hadgem2_es_racmo22e
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# pr_seasonal_anomaly_model_mpi_esm_lr_remo2009
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-40.0, '#ff543005'), (-20.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (20.0, '#ff35978f'), (40.0, '#ff003c30')]
# -----
# r95ptot_30yr_anomaly_seasonal_agree_model_ensemble
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-160.0, '#ff543005'), (-80.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (80.0, '#ff35978f'), (160.0, '#ff003c30')]
# -----
# r95ptot_30yr_anomaly_seasonal_model_ec_earth_cclm4_8_17
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-160.0, '#ff543005'), (-80.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (80.0, '#ff35978f'), (160.0, '#ff003c30')]
# -----
# r95ptot_30yr_anomaly_seasonal_model_ec_earth_racmo22e
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-160.0, '#ff543005'), (-80.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (80.0, '#ff35978f'), (160.0, '#ff003c30')]
# -----
# r95ptot_30yr_anomaly_seasonal_model_ec_earth_rca4
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-160.0, '#ff543005'), (-80.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (80.0, '#ff35978f'), (160.0, '#ff003c30')]
# -----
# r95ptot_30yr_anomaly_seasonal_model_hadgem2_es_racmo22e
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-160.0, '#ff543005'), (-80.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (80.0, '#ff35978f'), (160.0, '#ff003c30')]
# -----
# r95ptot_30yr_anomaly_seasonal_model_mpi_esm_lr_remo2009
# ['#FF543005', '#FF8c510a', '#FFbf812d', '#FFdfc27d', '#FFf6e8c3', '#FFf5f5f5', '#FFc7eae5', '#FF80cdc1', '#FF35978f', '#FF01665e', '#FF003c30']
# [(-160.0, '#ff543005'), (-80.0, '#ffbf812d'), (0.0, '#fff5f5f5'), (80.0, '#ff35978f'), (160.0, '#ff003c30')]
# -----
# snwdays_30yr_anomaly_annual_agree_model_ensemble
# ['#FF662506', '#FF993404', '#FFcc4c02', '#FFec7014', '#FFfe9929', '#FFfec44f', '#FFfee391', '#FFfff7bc', '#FFffffe5']
# [(-50.0, '#ff662506'), (-37.5, '#ffcc4c02'), (-25.0, '#fffe9929'), (-12.5, '#fffee391'), (0.0, '#ffffffe5')]
# -----
# snwdays_30yr_anomaly_annual_model_ec_earth_cclm4_8_17
# ['#FF662506', '#FF993404', '#FFcc4c02', '#FFec7014', '#FFfe9929', '#FFfec44f', '#FFfee391', '#FFfff7bc', '#FFffffe5']
# [(-50.0, '#ff662506'), (-37.5, '#ffcc4c02'), (-25.0, '#fffe9929'), (-12.5, '#fffee391'), (0.0, '#ffffffe5')]
# -----
# snwdays_30yr_anomaly_annual_model_ec_earth_racmo22e
# ['#FF662506', '#FF993404', '#FFcc4c02', '#FFec7014', '#FFfe9929', '#FFfec44f', '#FFfee391', '#FFfff7bc', '#FFffffe5']
# [(-50.0, '#ff662506'), (-37.5, '#ffcc4c02'), (-25.0, '#fffe9929'), (-12.5, '#fffee391'), (0.0, '#ffffffe5')]
# -----
# snwdays_30yr_anomaly_annual_model_ec_earth_rca4
# ['#FF662506', '#FF993404', '#FFcc4c02', '#FFec7014', '#FFfe9929', '#FFfec44f', '#FFfee391', '#FFfff7bc', '#FFffffe5']
# [(-50.0, '#ff662506'), (-37.5, '#ffcc4c02'), (-25.0, '#fffe9929'), (-12.5, '#fffee391'), (0.0, '#ffffffe5')]
# -----
# snwdays_30yr_anomaly_annual_model_hadgem2_es_racmo22e
# ['#FF662506', '#FF993404', '#FFcc4c02', '#FFec7014', '#FFfe9929', '#FFfec44f', '#FFfee391', '#FFfff7bc', '#FFffffe5']
# [(-50.0, '#ff662506'), (-37.5, '#ffcc4c02'), (-25.0, '#fffe9929'), (-12.5, '#fffee391'), (0.0, '#ffffffe5')]
# -----
# snwdays_30yr_anomaly_annual_model_mpi_esm_lr_remo2009
# ['#FF662506', '#FF993404', '#FFcc4c02', '#FFec7014', '#FFfe9929', '#FFfec44f', '#FFfee391', '#FFfff7bc', '#FFffffe5']
# [(-50.0, '#ff662506'), (-37.5, '#ffcc4c02'), (-25.0, '#fffe9929'), (-12.5, '#fffee391'), (0.0, '#ffffffe5')]
# -----
# snwdays_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# snwdays_annual_absolute_model_ec_earth_racmo22e
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# snwdays_annual_absolute_model_ec_earth_rca4
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# snwdays_annual_absolute_model_ensemble
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# snwdays_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# snwdays_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# snwdays_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# snwdays_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFFFFFD9', '#FF41B6C4', '#FF081D58']
# [(0.0, '#ffffffd9'), (25.0, '#ffffffd9'), (50.0, '#ff41b6c4'), (75.0, '#ff081d58'), (100.0, '#ff081d58')]
# -----
# su30_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (20.0, '#fffed976'), (40.0, '#fffd8d3c'), (60.0, '#ffe31a1c'), (80.0, '#ff800026')]
# -----
# su30_30yr_anomaly_annual_agree_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# su30_30yr_anomaly_annual_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# su30_30yr_anomaly_annual_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# su30_30yr_anomaly_annual_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# su30_30yr_anomaly_annual_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# su30_30yr_anomaly_annual_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# su30_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# su30_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (20.0, '#fffed976'), (40.0, '#fffd8d3c'), (60.0, '#ffe31a1c'), (80.0, '#ff800026')]
# -----
# tas_30yr_anomaly_seasonal_agree_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_30yr_anomaly_seasonal_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_30yr_anomaly_seasonal_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_30yr_anomaly_seasonal_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_30yr_anomaly_seasonal_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_30yr_anomaly_seasonal_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_annual_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_annual_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_annual_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_barometro_climatico
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_barometro_climatico_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_barometro_climatico_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmax_30yr_anomaly_seasonal_agree_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmax_30yr_anomaly_seasonal_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmax_30yr_anomaly_seasonal_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmax_30yr_anomaly_seasonal_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmax_30yr_anomaly_seasonal_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmax_30yr_anomaly_seasonal_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(7.0, '#ffffffcc'), (14.5, '#fffed976'), (22.0, '#fffd8d3c'), (29.5, '#ffe31a1c'), (37.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmax_seasonal_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmin_30yr_anomaly_seasonal_agree_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmin_30yr_anomaly_seasonal_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmin_30yr_anomaly_seasonal_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmin_30yr_anomaly_seasonal_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmin_30yr_anomaly_seasonal_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmin_30yr_anomaly_seasonal_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-13.0, '#ffffffcc'), (-3.0, '#fffed976'), (7.0, '#fffd8d3c'), (17.0, '#ffe31a1c'), (27.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tasmin_seasonal_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-3.0, '#ffffffcc'), (5.75, '#fffed976'), (14.5, '#fffd8d3c'), (23.25, '#ffe31a1c'), (32.0, '#ff800026')]
# -----
# tas_seasonal_anomaly_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_seasonal_anomaly_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_seasonal_anomaly_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_seasonal_anomaly_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_seasonal_anomaly_model_ensemble_lower_uncertainty
#
#
#
# SKIPPING
#
#
#
# -----
# tas_seasonal_anomaly_model_ensemble_upper_uncertainty
#
#
#
# SKIPPING
#
#
#
# -----
# tas_seasonal_anomaly_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tas_seasonal_anomaly_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (1.5, '#fffed976'), (3.0, '#fffd8d3c'), (4.5, '#ffe31a1c'), (6.0, '#ff800026')]
# -----
# tdd_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tdd_annual_monthly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tdd_annual_seasonal
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tdd_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tnd_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tnd_annual_monthly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tnd_annual_seasonal
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tnd_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# tr_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# tr_30yr_anomaly_annual_agree_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# tr_30yr_anomaly_annual_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# tr_30yr_anomaly_annual_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# tr_30yr_anomaly_annual_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# tr_30yr_anomaly_annual_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# tr_30yr_anomaly_annual_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (15.0, '#fffed976'), (35.0, '#fffd8d3c'), (55.0, '#ffe31a1c'), (75.0, '#ff800026')]
# -----
# tr_annual_absolute_model_ec_earth_cclm4_8_17
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (30.0, '#fffed976'), (60.0, '#fffd8d3c'), (90.0, '#ffe31a1c'), (120.0, '#ff800026')]
# -----
# tr_annual_absolute_model_ec_earth_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (30.0, '#fffed976'), (60.0, '#fffd8d3c'), (90.0, '#ffe31a1c'), (120.0, '#ff800026')]
# -----
# tr_annual_absolute_model_ec_earth_rca4
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (30.0, '#fffed976'), (60.0, '#fffd8d3c'), (90.0, '#ffe31a1c'), (120.0, '#ff800026')]
# -----
# tr_annual_absolute_model_ensemble
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (30.0, '#fffed976'), (60.0, '#fffd8d3c'), (90.0, '#ffe31a1c'), (120.0, '#ff800026')]
# -----
# tr_annual_absolute_model_ensemble_lower_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# tr_annual_absolute_model_ensemble_upper_uncertainty
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (25.0, '#fffed976'), (50.0, '#fffd8d3c'), (75.0, '#ffe31a1c'), (100.0, '#ff800026')]
# -----
# tr_annual_absolute_model_hadgem2_es_racmo22e
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (30.0, '#fffed976'), (60.0, '#fffd8d3c'), (90.0, '#ffe31a1c'), (120.0, '#ff800026')]
# -----
# tr_annual_absolute_model_mpi_esm_lr_remo2009
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (30.0, '#fffed976'), (60.0, '#fffd8d3c'), (90.0, '#ffe31a1c'), (120.0, '#ff800026')]
# -----
# tr_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(0.0, '#ffffffcc'), (12.5, '#fffed976'), (25.0, '#fffd8d3c'), (37.5, '#ffe31a1c'), (50.0, '#ff800026')]
# -----
# txd_30yr
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# txd_annual_monthly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# txd_annual_seasonal
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
# txd_annual_yearly
# ['#FFffffcc', '#FFffeda0', '#FFfed976', '#FFfeb24c', '#FFfd8d3c', '#FFfc4e2a', '#FFe31a1c', '#FFbd0026', '#FF800026']
# [(-5.0, '#ffffffcc'), (1.25, '#fffed976'), (7.5, '#fffd8d3c'), (13.75, '#ffe31a1c'), (20.0, '#ff800026')]
# -----
